# %%
import os
import tqdm
import random
import itertools
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

import tensorflow as tf
from tensorflow.keras.utils import *
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import *

import librosa

# %%
def plot_confusion_matrix(cm, classes, title='Confusion matrix', cmap=plt.cm.Blues):

    cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title, fontsize=25)
    
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90, fontsize=15)
    plt.yticks(tick_marks, classes, fontsize=15)

    fmt = '.2f'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black", fontsize = 14)

    plt.ylabel('True label', fontsize=20)
    plt.xlabel('Predicted label', fontsize=20)

# %%
label = pd.read_csv('profile.txt', sep='\t', header=None)
label.columns = ['Cooler','Valve','Pump','Accumulator','Flag']

df = pd.read_csv('EPS1.txt', sep='\t', header=None)

print(df.shape)
df.head()
# Out:
# (2205, 6000)
#      0       1       2       3       4       5       6       7       8     \
# 0  2411.6  2411.6  2411.6  2411.6  2411.6  2411.6  2411.6  2411.6  2411.6
# 1  2409.6  2409.6  2409.6  2409.6  2409.6  2409.6  2409.6  2409.6  2409.6
# 2  2397.8  2397.8  2397.8  2397.8  2397.8  2397.8  2397.8  2397.8  2397.8
# 3  2383.8  2383.8  2383.8  2383.8  2383.8  2383.8  2383.8  2383.8  2382.8
# 4  2372.0  2372.0  2372.0  2372.0  2372.0  2372.0  2372.0  2372.0  2372.0
#
#      9     ...    5990    5991    5992    5993    5994    5995    5996  \
# 0  2409.6  ...  2409.6  2409.2  2409.6  2409.4  2409.6  2409.4  2409.6
# 1  2409.6  ...  2398.8  2398.2  2398.2  2398.0  2398.0  2398.0  2398.0
# 2  2395.8  ...  2383.8  2383.8  2383.8  2383.8  2383.8  2383.8  2383.8
# 3  2382.8  ...  2373.2  2372.8  2372.6  2372.4  2372.2  2372.0  2372.0
# 4  2373.0  ...  2370.0  2370.0  2369.8  2369.8  2369.8  2369.8  2369.6
#
#      5997    5998    5999
# 0  2409.6  2409.6  2409.6
# 1  2397.8  2397.8  2397.8
# 2  2383.8  2383.8  2383.8
# 3  2372.0  2372.0  2372.0
# 4  2369.6  2369.6  2369.6
#
# [5 rows x 6000 columns]

# %%
df.iloc[2,:].plot(figsize=(12,8), title='Original Motor Power')
plt.ylabel('Motor Power (in W)'); plt.xlabel('Time')
# Out:
# Text(0.5, 0, 'Time')

# %%
df = df.values
df = np.clip(np.diff(df, axis=1), -5,5)
df.shape
# Out:
# (2205, 5999)

# %%
plt.figure(figsize=(12,8))
plt.plot(df[2])
plt.title('Standardized Motor Power')
plt.ylabel('First Difference'); plt.xlabel('Time')
np.set_printoptions(False)

# %%
# label distribution

label = label.Flag
label.value_counts()
# Out:
# 0    1449
# 1     756
# Name: Flag, dtype: int64

# %%
# label encoding
diz_label = {0:'stable', 1:'not stable'}
y = to_categorical(label)

# %%
df_mfcc = []

for i,sample in enumerate(tqdm.tqdm(df)):
    
    sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
    df_mfcc.append(sample_mfcc)
    
df_spectre = np.asarray(df_mfcc)
df_spectre = df_spectre.transpose(0,2,1)
df_spectre.shape

# (2205, 12, 20)
# Out:
#   0%|          | 0/2205 [00:00<?, ?it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   1%|          | 12/2205 [00:00<00:19, 113.51it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 1. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   1%|          | 24/2205 [00:00<00:19, 114.79it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -2.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 1. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -1.  1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0. -2.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   2%|▏         | 36/2205 [00:00<00:19, 113.22it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ... -0. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  0. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0. -0. ... -0. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -1.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 1. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  0. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   2%|▏         | 50/2205 [00:00<00:17, 122.62it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -0. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   3%|▎         | 63/2205 [00:00<00:17, 119.46it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 1. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 2. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -0.  0. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   3%|▎         | 77/2205 [00:00<00:17, 123.82it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 1. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0.  0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ...  0.  1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   4%|▍         | 91/2205 [00:00<00:16, 127.00it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -1. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   5%|▌         | 121/2205 [00:00<00:16, 129.78it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  2. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -1. -0. ...  3.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   6%|▌         | 137/2205 [00:01<00:15, 137.13it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  1.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -1. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ... -0. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  1.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   7%|▋         | 152/2205 [00:01<00:14, 140.57it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   8%|▊         | 167/2205 [00:01<00:16, 127.09it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 1. 1. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 0. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ...  2. -0.  2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  1. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   8%|▊         | 181/2205 [00:01<00:18, 111.93it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 0. 0. ... 0. 1. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -2.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1.  0. ... -1.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  2.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 1. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#   9%|▉         | 203/2205 [00:01<00:14, 137.80it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 1. 0. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 2.  0.  1. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  10%|█         | 227/2205 [00:01<00:12, 163.32it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ... -1. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  1. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 1. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -1.  2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -0.  1. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1.  1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  1.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  12%|█▏        | 271/2205 [00:01<00:10, 190.41it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0. -2. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -1. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  13%|█▎        | 291/2205 [00:01<00:09, 192.19it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -2.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  14%|█▍        | 311/2205 [00:02<00:09, 194.01it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -2.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0.  0. -3.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -1. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 0. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 1. 0. ... 2. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  15%|█▌        | 331/2205 [00:02<00:09, 194.77it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ...  0. -2.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  2.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0. -0. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  1. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -2. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  16%|█▌        | 355/2205 [00:02<00:08, 206.35it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-3.  0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1. -2. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 2. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  17%|█▋        | 378/2205 [00:02<00:08, 212.83it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  0. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  18%|█▊        | 402/2205 [00:02<00:08, 220.34it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  20%|██        | 448/2205 [00:02<00:07, 223.74it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  1. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -1.  0. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 2.  1.  1. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  1.  1. ... -1. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  21%|██▏       | 471/2205 [00:02<00:07, 222.49it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  22%|██▏       | 496/2205 [00:02<00:07, 228.09it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-2.  0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  1. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0. -1.  2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -0.  0. ... -1. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  24%|██▎       | 520/2205 [00:03<00:07, 230.42it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  25%|██▍       | 544/2205 [00:03<00:07, 232.72it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -1. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -2.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0.  0. -3.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  26%|██▌       | 569/2205 [00:03<00:06, 235.26it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -0.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ... -1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  27%|██▋       | 593/2205 [00:03<00:06, 232.74it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  28%|██▊       | 618/2205 [00:03<00:06, 234.55it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -0. -0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0.  2.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  30%|███       | 666/2205 [00:03<00:06, 230.87it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 0. ... 3. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  0. ...  2. -0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 0. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  1. -0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  31%|███▏      | 690/2205 [00:03<00:06, 225.83it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 1. 2. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -0. ...  0. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  0.  0.  2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 0. 0. ... 0. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[2. 1. 1. ... 0. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1. -1. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  1.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0.  0. ... -0.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  32%|███▏      | 713/2205 [00:03<00:06, 224.65it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  0. -2.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -1. -1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-2. -0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 2. -2.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -1.  0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  33%|███▎      | 737/2205 [00:03<00:06, 228.53it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  1.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -2. ...  0.  2.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  1.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# ...
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  75%|███████▌  | 1655/2205 [00:08<00:02, 216.81it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ...  1. -1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  1.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ... -1. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  2.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0.  0. ...  1.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -1. ...  0. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -1. -0. ... -0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  76%|███████▌  | 1679/2205 [00:08<00:02, 223.03it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  2.  0. ... -2. -1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1.  0. ... -0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  0.  1. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  77%|███████▋  | 1704/2205 [00:08<00:02, 228.40it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -0.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0. -1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  78%|███████▊  | 1728/2205 [00:08<00:02, 229.59it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0. -2.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  79%|███████▉  | 1752/2205 [00:09<00:01, 231.46it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1.  2. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  81%|████████  | 1776/2205 [00:09<00:01, 231.44it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -0. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1.  0. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  83%|████████▎ | 1824/2205 [00:09<00:01, 232.83it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  2. -0. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  1. -0. ...  0.  0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  2. -0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 1. ... 2. 1. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1. -1. -0. ...  1. -1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  84%|████████▍ | 1849/2205 [00:09<00:01, 235.99it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[2. 0. 1. ... 1. 0. 0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 0. 1. ... 1. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -2. -2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  85%|████████▍ | 1874/2205 [00:09<00:01, 238.20it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1.  1.  0. ... -1. -2. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ... -1. -1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[0. 1. 0. ... 0. 1. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ... -1. -0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  1. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ... -0. -0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  86%|████████▌ | 1899/2205 [00:09<00:01, 239.05it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0. -0. ...  0. -1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  87%|████████▋ | 1923/2205 [00:09<00:01, 237.45it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -2.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 1. -0.  1. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  1. ...  0.  0.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  88%|████████▊ | 1948/2205 [00:09<00:01, 239.20it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0. -0. -0. ...  0.  0. -3.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -1. ...  0.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  89%|████████▉ | 1972/2205 [00:09<00:00, 238.25it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 0. 1. ... 0. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  92%|█████████▏| 2022/2205 [00:10<00:00, 239.67it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  1.  0. ...  1.  0. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1. -0. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ... -2.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0.  0. ...  0. -1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  93%|█████████▎| 2047/2205 [00:10<00:00, 239.96it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-0.  0.  0. ... -1.  1. -0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  94%|█████████▍| 2071/2205 [00:10<00:00, 239.46it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ...  0.  1.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  97%|█████████▋| 2146/2205 [00:10<00:00, 230.99it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[1. 1. 1. ... 0. 0. 1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -0. -1. ... -1.  1. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0. -1. ...  0.  0.  2.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
#  98%|█████████▊| 2171/2205 [00:10<00:00, 234.58it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0.  0.  0. ...  0. -0.  1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[-1.  0. -0. ...  0.  1.  0.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# 100%|█████████▉| 2196/2205 [00:10<00:00, 236.97it/s]C:\Users\BalciAl\AppData\Local\Temp\ipykernel_25368\2732344136.py:7: FutureWarning: Pass y=[ 0. -1.  0. ... -1.  0. -1.] as keyword args. From version 0.10 passing these as positional arguments will result in an error
#   sample_mfcc = librosa.feature.mfcc(np.asfortranarray(sample),sr=40000)
# 100%|██████████| 2205/2205 [00:10<00:00, 201.26it/s]
# (2205, 12, 20)

# %%
plt.figure(figsize=(12,8))

plt.plot(df_spectre[2])
plt.legend(['mfcc_'+str(i) for i in range(df_spectre.shape[-1])], 
          loc='center left', bbox_to_anchor=(1, 0.5))
plt.title('MFCC features')
plt.ylabel('Amplitudes'); plt.xlabel('Time')

np.set_printoptions(False)

# %%
# train test split

X_train, X_test, y_train, y_test = train_test_split(df_spectre, y, random_state = 42, test_size=0.2)

# %%
# resnet cnn 

def set_seed(seed):
    
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)
    

def get_model(data):
    
    set_seed(33)
        
    def residual_block(init, hidden_dim):
        
        init = Conv1D(hidden_dim, 3, activation='relu', padding="same")(init)
        
        x = Conv1D(hidden_dim, 3, activation='relu', padding="same")(init)
        x = Conv1D(hidden_dim, 3, activation='relu', padding="same")(x)
        x = Conv1D(hidden_dim, 3, activation='relu', padding="same")(x)
        skip = Add()([x, init])
        
        return skip
    
    
    inp = Input(shape=(data.shape[1], data.shape[2]))
    
    x = residual_block(inp, 256)
    x = residual_block(x, 128)
    x = residual_block(x, 32)
    x = GlobalMaxPool1D()(x)
    
    out = Dense(len(diz_label), activation='softmax')(x)
    
    model = Model(inputs=inp, outputs=out)
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    return model

# %%
es = EarlyStopping(monitor='val_accuracy', mode='auto', restore_best_weights=True, verbose=1, patience=15)

model = get_model(X_train)
model.fit(X_train, y_train, epochs=100, batch_size=256, verbose=2, validation_split=0.1, callbacks=[es])
# Out:
# Epoch 1/100
# 7/7 - 2s - loss: 7.1103 - accuracy: 0.5583 - val_loss: 1.0679 - val_accuracy: 0.4463 - 2s/epoch - 338ms/step
# Epoch 2/100
# 7/7 - 1s - loss: 1.3317 - accuracy: 0.5759 - val_loss: 0.8976 - val_accuracy: 0.4633 - 783ms/epoch - 112ms/step
# Epoch 3/100
# 7/7 - 1s - loss: 0.9735 - accuracy: 0.5816 - val_loss: 0.6906 - val_accuracy: 0.5706 - 872ms/epoch - 125ms/step
# Epoch 4/100
# 7/7 - 1s - loss: 0.7159 - accuracy: 0.5816 - val_loss: 0.6332 - val_accuracy: 0.6384 - 1s/epoch - 151ms/step
# Epoch 5/100
# 7/7 - 1s - loss: 0.6025 - accuracy: 0.6723 - val_loss: 0.5719 - val_accuracy: 0.7006 - 1s/epoch - 149ms/step
# Epoch 6/100
# 7/7 - 1s - loss: 0.5830 - accuracy: 0.6761 - val_loss: 0.6001 - val_accuracy: 0.6328 - 1s/epoch - 146ms/step
# Epoch 7/100
# 7/7 - 1s - loss: 0.5742 - accuracy: 0.6686 - val_loss: 0.7187 - val_accuracy: 0.6215 - 1s/epoch - 152ms/step
# Epoch 8/100
# 7/7 - 1s - loss: 0.6260 - accuracy: 0.6541 - val_loss: 0.5688 - val_accuracy: 0.6554 - 1s/epoch - 181ms/step
# Epoch 9/100
# 7/7 - 1s - loss: 0.5649 - accuracy: 0.6799 - val_loss: 0.5771 - val_accuracy: 0.6836 - 1s/epoch - 160ms/step
# Epoch 10/100
# 7/7 - 1s - loss: 0.5834 - accuracy: 0.6856 - val_loss: 0.6039 - val_accuracy: 0.6441 - 1s/epoch - 158ms/step
# Epoch 11/100
# 7/7 - 1s - loss: 0.5316 - accuracy: 0.7164 - val_loss: 0.4981 - val_accuracy: 0.7797 - 1s/epoch - 163ms/step
# Epoch 12/100
# 7/7 - 1s - loss: 0.5043 - accuracy: 0.7505 - val_loss: 0.4905 - val_accuracy: 0.7684 - 1s/epoch - 174ms/step
# Epoch 13/100
# 7/7 - 1s - loss: 0.4941 - accuracy: 0.7593 - val_loss: 0.6262 - val_accuracy: 0.6441 - 1s/epoch - 151ms/step
# Epoch 14/100
# 7/7 - 1s - loss: 0.5822 - accuracy: 0.6793 - val_loss: 0.5778 - val_accuracy: 0.6554 - 1s/epoch - 143ms/step
# Epoch 15/100
# 7/7 - 1s - loss: 0.5138 - accuracy: 0.7492 - val_loss: 0.4654 - val_accuracy: 0.8136 - 1s/epoch - 150ms/step
# Epoch 16/100
# 7/7 - 1s - loss: 0.4795 - accuracy: 0.7719 - val_loss: 0.4822 - val_accuracy: 0.7514 - 1s/epoch - 163ms/step
# Epoch 17/100
# 7/7 - 1s - loss: 0.4636 - accuracy: 0.7883 - val_loss: 0.4584 - val_accuracy: 0.7797 - 1s/epoch - 157ms/step
# Epoch 18/100
# 7/7 - 1s - loss: 0.4584 - accuracy: 0.7820 - val_loss: 0.4449 - val_accuracy: 0.8136 - 1s/epoch - 164ms/step
# Epoch 19/100
# 7/7 - 1s - loss: 0.4639 - accuracy: 0.7769 - val_loss: 0.4413 - val_accuracy: 0.7910 - 1s/epoch - 196ms/step
# Epoch 20/100
# 7/7 - 1s - loss: 0.4454 - accuracy: 0.7971 - val_loss: 0.4510 - val_accuracy: 0.8192 - 1s/epoch - 153ms/step
# Epoch 21/100
# 7/7 - 1s - loss: 0.4748 - accuracy: 0.7637 - val_loss: 0.5376 - val_accuracy: 0.6836 - 1s/epoch - 152ms/step
# Epoch 22/100
# 7/7 - 1s - loss: 0.4581 - accuracy: 0.7776 - val_loss: 0.4255 - val_accuracy: 0.8305 - 1s/epoch - 179ms/step
# Epoch 23/100
# 7/7 - 1s - loss: 0.4446 - accuracy: 0.7977 - val_loss: 0.4293 - val_accuracy: 0.8305 - 1s/epoch - 174ms/step
# Epoch 24/100
# 7/7 - 1s - loss: 0.4264 - accuracy: 0.8028 - val_loss: 0.5339 - val_accuracy: 0.7006 - 1s/epoch - 183ms/step
# Epoch 25/100
# 7/7 - 1s - loss: 0.4489 - accuracy: 0.7769 - val_loss: 0.4056 - val_accuracy: 0.8305 - 1s/epoch - 177ms/step
# Epoch 26/100
# 7/7 - 1s - loss: 0.4187 - accuracy: 0.8129 - val_loss: 0.4044 - val_accuracy: 0.8305 - 1s/epoch - 154ms/step
# Epoch 27/100
# 7/7 - 1s - loss: 0.4227 - accuracy: 0.8084 - val_loss: 0.4126 - val_accuracy: 0.8305 - 1s/epoch - 156ms/step
# Epoch 28/100
# 7/7 - 1s - loss: 0.3991 - accuracy: 0.8399 - val_loss: 0.4170 - val_accuracy: 0.8079 - 1s/epoch - 177ms/step
# Epoch 29/100
# 7/7 - 1s - loss: 0.3914 - accuracy: 0.8280 - val_loss: 0.3926 - val_accuracy: 0.8418 - 1s/epoch - 169ms/step
# Epoch 30/100
# 7/7 - 1s - loss: 0.3939 - accuracy: 0.8223 - val_loss: 0.4181 - val_accuracy: 0.7966 - 1s/epoch - 160ms/step
# Epoch 31/100
# 7/7 - 1s - loss: 0.3894 - accuracy: 0.8355 - val_loss: 0.4490 - val_accuracy: 0.7797 - 1s/epoch - 154ms/step
# Epoch 32/100
# 7/7 - 1s - loss: 0.3838 - accuracy: 0.8280 - val_loss: 0.3939 - val_accuracy: 0.8305 - 1s/epoch - 156ms/step
# Epoch 33/100
# 7/7 - 1s - loss: 0.3832 - accuracy: 0.8330 - val_loss: 0.3734 - val_accuracy: 0.8362 - 1s/epoch - 164ms/step
# Epoch 34/100
# 7/7 - 1s - loss: 0.3489 - accuracy: 0.8488 - val_loss: 0.4493 - val_accuracy: 0.7910 - 1s/epoch - 156ms/step
# Epoch 35/100
# 7/7 - 1s - loss: 0.3874 - accuracy: 0.8324 - val_loss: 0.3987 - val_accuracy: 0.8192 - 1s/epoch - 149ms/step
# Epoch 36/100
# 7/7 - 1s - loss: 0.3513 - accuracy: 0.8463 - val_loss: 0.3701 - val_accuracy: 0.8588 - 1s/epoch - 148ms/step
# Epoch 37/100
# 7/7 - 1s - loss: 0.3605 - accuracy: 0.8412 - val_loss: 0.3425 - val_accuracy: 0.8531 - 1s/epoch - 145ms/step
# Epoch 38/100
# 7/7 - 1s - loss: 0.3192 - accuracy: 0.8677 - val_loss: 0.3895 - val_accuracy: 0.8136 - 1s/epoch - 146ms/step
# Epoch 39/100
# 7/7 - 1s - loss: 0.3308 - accuracy: 0.8544 - val_loss: 0.3273 - val_accuracy: 0.8588 - 1s/epoch - 146ms/step
# Epoch 40/100
# 7/7 - 1s - loss: 0.3034 - accuracy: 0.8702 - val_loss: 0.3338 - val_accuracy: 0.8588 - 1s/epoch - 148ms/step
# Epoch 41/100
# 7/7 - 1s - loss: 0.3046 - accuracy: 0.8897 - val_loss: 0.3503 - val_accuracy: 0.8531 - 1s/epoch - 146ms/step
# Epoch 42/100
# 7/7 - 1s - loss: 0.3106 - accuracy: 0.8670 - val_loss: 0.3225 - val_accuracy: 0.8531 - 1s/epoch - 158ms/step
# Epoch 43/100
# 7/7 - 1s - loss: 0.2875 - accuracy: 0.8771 - val_loss: 0.3589 - val_accuracy: 0.8362 - 1s/epoch - 167ms/step
# Epoch 44/100
# 7/7 - 1s - loss: 0.2985 - accuracy: 0.8740 - val_loss: 0.2847 - val_accuracy: 0.8927 - 1s/epoch - 159ms/step
# Epoch 45/100
# 7/7 - 1s - loss: 0.2837 - accuracy: 0.8752 - val_loss: 0.3016 - val_accuracy: 0.8701 - 1s/epoch - 153ms/step
# Epoch 46/100
# 7/7 - 1s - loss: 0.3230 - accuracy: 0.8463 - val_loss: 0.3810 - val_accuracy: 0.8136 - 1s/epoch - 154ms/step
# Epoch 47/100
# 7/7 - 1s - loss: 0.3030 - accuracy: 0.8595 - val_loss: 0.3057 - val_accuracy: 0.8870 - 1s/epoch - 160ms/step
# Epoch 48/100
# 7/7 - 1s - loss: 0.2578 - accuracy: 0.9017 - val_loss: 0.2839 - val_accuracy: 0.8927 - 1s/epoch - 157ms/step
# Epoch 49/100
# 7/7 - 1s - loss: 0.2461 - accuracy: 0.9042 - val_loss: 0.4293 - val_accuracy: 0.7910 - 1s/epoch - 151ms/step
# Epoch 50/100
# 7/7 - 1s - loss: 0.3127 - accuracy: 0.8551 - val_loss: 0.3626 - val_accuracy: 0.8305 - 1s/epoch - 155ms/step
# Epoch 51/100
# 7/7 - 1s - loss: 0.2979 - accuracy: 0.8639 - val_loss: 0.3661 - val_accuracy: 0.8305 - 1s/epoch - 156ms/step
# Epoch 52/100
# 7/7 - 1s - loss: 0.2702 - accuracy: 0.8885 - val_loss: 0.3295 - val_accuracy: 0.8362 - 1s/epoch - 156ms/step
# Epoch 53/100
# 7/7 - 1s - loss: 0.2682 - accuracy: 0.8796 - val_loss: 0.3217 - val_accuracy: 0.8305 - 1s/epoch - 154ms/step
# Epoch 54/100
# 7/7 - 1s - loss: 0.2575 - accuracy: 0.8916 - val_loss: 0.3321 - val_accuracy: 0.8588 - 1s/epoch - 153ms/step
# Epoch 55/100
# 7/7 - 1s - loss: 0.2553 - accuracy: 0.8922 - val_loss: 0.4562 - val_accuracy: 0.7797 - 1s/epoch - 159ms/step
# Epoch 56/100
# 7/7 - 1s - loss: 0.2912 - accuracy: 0.8683 - val_loss: 0.3181 - val_accuracy: 0.8475 - 1s/epoch - 151ms/step
# Epoch 57/100
# 7/7 - 1s - loss: 0.2971 - accuracy: 0.8633 - val_loss: 0.5056 - val_accuracy: 0.7684 - 959ms/epoch - 137ms/step
# Epoch 58/100
# 7/7 - 1s - loss: 0.3061 - accuracy: 0.8544 - val_loss: 0.3795 - val_accuracy: 0.8249 - 1s/epoch - 151ms/step
# Epoch 59/100
# Restoring model weights from the end of the best epoch: 44.
# 7/7 - 1s - loss: 0.2740 - accuracy: 0.8752 - val_loss: 0.2768 - val_accuracy: 0.8870 - 998ms/epoch - 143ms/step
# Epoch 59: early stopping

# %%
pred_test = np.argmax(model.predict(X_test), axis=1)
# Out:
# 14/14 [==============================] - 0s 7ms/step

# %%
print(classification_report([diz_label[np.argmax(label)] for label in y_test], 
                            [diz_label[label] for label in pred_test]))
# Out:
#               precision    recall  f1-score   support
#
#   not stable       0.81      0.73      0.77       147
#       stable       0.87      0.91      0.89       294
#
#     accuracy                           0.85       441
#    macro avg       0.84      0.82      0.83       441
# weighted avg       0.85      0.85      0.85       441

# %%
cnf_matrix = confusion_matrix([diz_label[np.argmax(label)] for label in y_test], 
                              [diz_label[label] for label in pred_test])

plt.figure(figsize=(7,7))
plot_confusion_matrix(cnf_matrix, classes=list(diz_label.values()))
plt.show()

# %%
sum([diz_label[np.argmax(label)] == 'stable' for label in y_test]) / len(pred_test)
# Out:
# 0.6666666666666666
